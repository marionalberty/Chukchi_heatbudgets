# %% [markdown]
# # Check v10 pp issue
# Even though some pp files for the v10 experiment are identical to the v5 files, ensure the history files are correct

# %%
import xarray as xr

# %%
base = '/archive/Marion.Alberty/FMS2021.02_mom6_devgfdl_20221223/'
hist = 'gfdl.ncrc4-intel18-prod/history/20080101.ocean_daily.nc'
pv10 = 'OM4p25_JRA55do1.4_0netfw_cde.02_BWP_68.193_Lx300_Ly500_tau28_v10/'
pv5 = 'OM4p25_JRA55do1.4_0netfw_cde.02_BWP_68.193_Lx300_Ly500_tau28_v5/'

# %%
v2drop = ['average_DT', 'average_T1', 'average_T2','time_bnds']

# %%
DS10 = xr.open_mfdataset(f'{base}{pv10}{hist}',use_cftime=True,combine='by_coords',
                         engine='netcdf4',drop_variables=v2drop)

# %%
DS5 = xr.open_mfdataset(f'{base}{pv5}{hist}',use_cftime=True,combine='by_coords',
                         engine='netcdf4',drop_variables=v2drop)

# %%
DS10
# Out:
# <xarray.Dataset>
# Dimensions:   (nv: 2, time: 366, xh: 1440, xq: 1440, yh: 1080, yq: 1080)
# Coordinates:
#   * xh        (xh) float64 -299.7 -299.5 -299.2 -299.0 ... 59.53 59.78 60.03
#   * yh        (yh) float64 -80.39 -80.31 -80.23 -80.15 ... 89.73 89.84 89.95
#   * time      (time) object 2008-01-01 12:00:00 ... 2008-12-31 12:00:00
#   * nv        (nv) float64 1.0 2.0
#   * xq        (xq) float64 -299.6 -299.3 -299.1 -298.9 ... 59.66 59.91 60.16
#   * yq        (yq) float64 -80.35 -80.27 -80.19 -80.11 ... 89.78 89.89 90.0
# Data variables:
#     mlotst    (time, yh, xh) float32 dask.array<chunksize=(366, 1080, 1440), meta=np.ndarray>
#     ssu       (time, yh, xq) float32 dask.array<chunksize=(366, 1080, 1440), meta=np.ndarray>
#     ssv       (time, yq, xh) float32 dask.array<chunksize=(366, 1080, 1440), meta=np.ndarray>
#     tos       (time, yh, xh) float32 dask.array<chunksize=(366, 1080, 1440), meta=np.ndarray>
# ...

# %%
DS5
# Out:
# <xarray.Dataset>
# Dimensions:   (nv: 2, time: 366, xh: 1440, xq: 1440, yh: 1080, yq: 1080)
# Coordinates:
#   * xh        (xh) float64 -299.7 -299.5 -299.2 -299.0 ... 59.53 59.78 60.03
#   * yh        (yh) float64 -80.39 -80.31 -80.23 -80.15 ... 89.73 89.84 89.95
#   * time      (time) object 2008-01-01 12:00:00 ... 2008-12-31 12:00:00
#   * nv        (nv) float64 1.0 2.0
#   * xq        (xq) float64 -299.6 -299.3 -299.1 -298.9 ... 59.66 59.91 60.16
#   * yq        (yq) float64 -80.35 -80.27 -80.19 -80.11 ... 89.78 89.89 90.0
# Data variables:
#     mlotst    (time, yh, xh) float32 dask.array<chunksize=(366, 1080, 1440), meta=np.ndarray>
#     ssu       (time, yh, xq) float32 dask.array<chunksize=(366, 1080, 1440), meta=np.ndarray>
#     ssv       (time, yq, xh) float32 dask.array<chunksize=(366, 1080, 1440), meta=np.ndarray>
#     tos       (time, yh, xh) float32 dask.array<chunksize=(366, 1080, 1440), meta=np.ndarray>
# ...

# %%
(DS10['tauy'] - DS5['tauy']).mean('time').plot()
# Out:
# /nbhome/Marion.Alberty/miniconda/envs/phys_ocean/lib/python3.8/site-packages/dask/array/numpy_compat.py:40: RuntimeWarning: invalid value encountered in true_divide
#   x = np.divide(x1, x2, out)

# %% [markdown]
# # These history files are different! phew
